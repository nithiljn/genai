# %%
# !pip install google-ai-generativelanguage
# Out:
# Requirement already satisfied: google-ai-generativelanguage in /usr/local/lib/python3.10/dist-packages (0.6.4)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage) (2.11.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.63.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2024.6.2)
# ERROR: Operation cancelled by user

# %%
import pathlib
import textwrap
import google.generativeai as genai
from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown

def rs(text):
   text = text.replace('*',' *')
   return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCZNAhvSw3DfiSvkDOhyzh8ktoIcuzKTuk"

# %%
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
r= model.generate_content("tell about indian cricket?")

# %%
rs(r.text)
# Out:
# >  * *Indian Cricket * *
# >
# >  * *History: * *
# >
# >  * Cricket was introduced to India by the British in the mid-18th century.
# >  * The first official cricket match in India was played in Calcutta (now Kolkata) in 1792.
# >  * India became a Test-playing nation in 1932.
# >
# >  * *Governing Body: * *
# >
# >  * Board of Control for Cricket in India (BCCI)
# >
# >  * *National Team: * *
# >
# >  * Known as the "Men in Blue"
# >  * Captained by Rohit Sharma (T20Is and ODIs), and Virat Kohli (Tests)
# >  * Ranked among the top teams in the world in all formats
# >
# >  * *Key Players: * *
# >
# >  * Virat Kohli (batsman)
# >  * Rohit Sharma (batsman)
# >  * Jasprit Bumrah (fast bowler)
# >  * Ravichandran Ashwin (spin bowler)
# >  * MS Dhoni (former captain and wicket-keeper batsman)
# >
# >  * *Tournaments: * *
# >
# >  * Indian Premier League (IPL): A Twenty20 league featuring eight franchises.
# >  * Ranji Trophy: A first-class tournament for domestic teams.
# >  * Vijay Hazare Trophy: A 50-over tournament for domestic teams.
# >
# >  * *Stadiums: * *
# >
# >  * Eden Gardens, Kolkata
# >  * Wankhede Stadium, Mumbai
# >  * Narendra Modi Stadium, Ahmedabad
# >  * Arun Jaitley Stadium, Delhi
# >
# >  * *Key Achievements: * *
# >
# >  * Won two Cricket World Cups (1983, 2011)
# >  * Won the 2007 ICC World Twenty20
# >  * Won the 2013 ICC Champions Trophy
# >  * Won the inaugural ICC Test Championship (2019-2021)
# >
# >  * *Culture: * *
# >
# >  * Cricket is deeply ingrained in Indian culture and is considered the national sport.
# >  * Matches often attract large crowds and are followed passionately by millions of fans.
# >  * The Indian Premier League is one of the most popular sporting events in the world.
# >
# >  * *Economic Impact: * *
# >
# >  * The cricket industry in India generates billions of dollars in revenue.
# >  * It creates numerous employment opportunities and supports various related industries.
# >
# >  * *Other Aspects: * *
# >
# >  * India has a strong tradition of spin bowling.
# >  * The "Chinaman" style of spin bowling was developed in India.
# >  * Indian cricketers are known for their technical skills and aggressive approach to the game.
# >  * The sport has played a significant role in fostering national unity and pride in India.

# %%
akash = model.generate_content("find the value of pie?")

# %%
rs(akash.text)
# Out:
# >  * *π (pi) * *
# >
# > Pi is an irrational number, meaning it cannot be expressed as a simple fraction a/b. It is approximately equal to 3.14159.
# >
# >  * *Exact Value: * *
# >
# > Pi has no finite decimal expansion. Its exact value can be represented using the following infinite series:
# >
# > ```
# > π = 3 + 1/7 - 1/5 + 1/31 - 1/11 + 1/17 - 1/13 + ...
# > ```
# >
# >  * *Common Approximations: * *
# >
# >  *  * *3.14 (2 decimal places) * *
# >  *  * *3.1415 (4 decimal places) * *
# >  *  * *3.14159 (5 decimal places) * *
# >
# >  * *Historical Calculations: * *
# >
# > Archimedes (c. 250 BC) first estimated pi using polygons inscribed in and circumscribed around a circle. He obtained approximations of 3.1028 and 3.1791, respectively.
# >
# > Later, mathematicians like Srinivasa Ramanujan developed more sophisticated formulas to calculate the value of pi to even higher precision.
# >
# >  * *Applications: * *
# >
# > Pi is used in various fields, including:
# >
# >  * Geometry (calculating the circumference and area of circles)
# >  * Trigonometry
# >  * Calculus
# >  * Physics (for example, in the formula for the period of a pendulum)
# >  * Computer science

# %%
nithil = model.generate_content("do you know Knowledge Institute of Technology(KIOT),kakapalayam, in salem district pincode-637504 ,india?")

# %%
rs(nithil.text)
# Out:
# > Yes, I know about Knowledge Institute of Technology (KIOT) in Kakapalayam, Salem district, India, with a pincode of 637504.
# >
# >  * *About KIOT: * *
# >
# > Knowledge Institute of Technology (KIOT) is a private engineering college located in the town of Kakapalayam, 20 kilometers from the city of Salem in Tamil Nadu, India. It was established in 2008 and is affiliated with Anna University in Chennai.
# >
# >  * *Courses Offered: * *
# >
# > KIOT offers undergraduate and postgraduate programs in various engineering disciplines, including:
# >
# >  *  * *Undergraduate Programs: * *
# >      * B.E. in Computer Science and Engineering
# >      * B.E. in Electronics and Communication Engineering
# >      * B.E. in Electrical and Electronics Engineering
# >      * B.E. in Mechanical Engineering
# >      * B.E. in Civil Engineering
# >  *  * *Postgraduate Programs: * *
# >      * M.E. in Computer Science and Engineering
# >      * M.E. in Electronics and Communication Engineering
# >      * M.E. in Power Systems Engineering
# >
# >  * *Facilities: * *
# >
# > KIOT has a modern campus with state-of-the-art facilities, including:
# >
# >  * Well-equipped laboratories
# >  * Spacious classrooms
# >  * Computer center
# >  * Library with a vast collection of books and journals
# >  * Sports facilities
# >  * Hostel accommodation
# >
# >  * *Accreditation: * *
# >
# > KIOT is accredited by the National Board of Accreditation (NBA) and is recognized by the All India Council for Technical Education (AICTE).
# >
# >  * *Contact Information: * *
# >
# > Knowledge Institute of Technology
# > Kakapalayam
# > Salem District, Tamil Nadu 637504
# > India
# >
# >  * *Phone: * * +91-427-2370004
# >  * *Website: * * https://www.kiot.ac.in/

# %%
james = model.generate_content("Tell me a joke?")

# %%
rs(james.text)
# Out:
# > Why did the scarecrow win an award?
# >
# > Because he was outstanding in his field!

# %%
import PIL
img = PIL.Image.open("download.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=148x148>

# %%
model1 = genai.GenerativeModel('gemini-pro-vision')

# %%
r1 = model1.generate_content(img)
rs(r1.text)
# Out:
# >  The picture shows two cute kittens cuddling up against each other. The kittens are both looking at the camera with big, round eyes. Their fur is soft and fluffy. The background of the picture is a sunset in warm colors.

# %%
img1 = PIL.Image.open("ji.jpeg")
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
ui= model1.generate_content(img1)

# %%
rs(ui.text)
# Out:
# >  The picture shows a group of people climbing a mountain. One person is at the top, and he is reaching down to help the others up. This picture is a metaphor for teamwork. It shows that if we work together, we can achieve anything.
# >
# > In the workplace, teamwork is essential. We need to be able to work with others to get the job done. This means being able to communicate effectively, cooperate, and compromise. When we work together, we can achieve more than we could ever achieve on our own.
# >
# > Here are some tips for working effectively in a team:
# >
# >  *  * *Be clear about your goals. * * What do you want to achieve? Make sure everyone on the team is on the same page.
# >  *  * *Communicate openly and honestly. * * Share your ideas and thoughts, and be willing to listen to others.
# >  *  * *Be cooperative and willing to compromise. * * Sometimes, you need to give and take to get the job done.
# >  *  * *Be supportive and encouraging. * * Help your teammates succeed, and celebrate their successes.
# >
# > When we work together, we can achieve anything. So let's work together and make a difference in the world.
